# %%
# %pip install librosa
# %pip install matplotlib
# %pip install pandas
# %pip install sklearn
# %pip install crepe
# %pip install tensorflow
# Out:
# Requirement already satisfied: librosa in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from numba>=0.51.0->librosa) (7.1.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from importlib-metadata->numba>=0.51.0->librosa) (3.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (3.7.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: crepe in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (0.0.15)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (1.24.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (1.10.1)
# Requirement already satisfied: matplotlib>=2.1.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (3.7.5)
# Requirement already satisfied: resampy<0.3.0,>=0.2.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (0.2.2)
# Requirement already satisfied: h5py in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (3.11.0)
# Requirement already satisfied: hmmlearn>=0.3.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (0.3.2)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (2.34.1)
# Requirement already satisfied: scikit-learn>=0.16 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from crepe) (1.2.2)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from imageio>=2.3.0->crepe) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from matplotlib>=2.1.0->crepe) (6.4.0)
# Requirement already satisfied: numba>=0.32 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from resampy<0.3.0,>=0.2.0->crepe) (0.58.1)
# Requirement already satisfied: six>=1.3 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from resampy<0.3.0,>=0.2.0->crepe) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from scikit-learn>=0.16->crepe) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from scikit-learn>=0.16->crepe) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=2.1.0->crepe) (3.17.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from numba>=0.32->resampy<0.3.0,>=0.2.0->crepe) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from numba>=0.32->resampy<0.3.0,>=0.2.0->crepe) (7.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (2.13.0)
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (7.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\junio\documents\3ero\mtw\raga-bhairavi-pattern-identification\.conda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import IPython.display as ipd
import sklearn
import crepe

# %%
# Load the WAV file
#audio_file = "./101_mono.wav"

#y, sr = librosa.load(audio_file, sr=None)  # sr=None to preserve the original sampling rate

#Display audio
#ipd.Audio(audio_file)

# %%
def generate_fake_audio(duration, sample_rate):
    """
    Generate fake audio data.

    Args:
    - duration (float): Duration of the audio signal in seconds.
    - sample_rate (int): Sampling rate of the audio signal.

    Returns:
    - numpy.ndarray: Fake audio data.
    """
    # Calculate the number of samples
    num_samples = int(duration * sample_rate)

    # Generate a random audio signal (e.g., white noise)
    audio_data = np.random.normal(0, 1, num_samples)

    return audio_data

# Example usage:
duration = 5  # 5 seconds
sample_rate = 44100  # 44.1 kHz
y = generate_fake_audio(duration, sample_rate)

# %%
#Show audio waveform
plt.figure(figsize=(20, 5))
librosa.display.waveshow(y, sr=sample_rate, color="blue")
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Waveform')
plt.show()

# %%
# Size of the Fast Fourier Transform (FFT), which will also be used as the window length
n_fft=1024

# Step or stride between windows. If the step is smaller than the window length, the windows will overlap
hop_length=320

# Specify the window type for FFT/STFT
window_type ='hann'

# Calculate the spectrogram as the square of the complex magnitude of the STFT
spectrogram_librosa = np.abs(librosa.stft(y, n_fft=n_fft, hop_length=hop_length, win_length=n_fft, window=window_type)) ** 2

# %%
#Log Mel Spectrogram
mel_bins = 64 # Number of Mel bands
fmin = 0
fmax = None
mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sample_rate, n_fft=n_fft, hop_length=hop_length, win_length=n_fft, window=window_type, n_mels = mel_bins, power=2.0)


mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
librosa.display.specshow(mel_spectrogram_db, sr=sample_rate, x_axis='time', y_axis='mel',hop_length=hop_length)
plt.colorbar(format='%+2.0f dB')
plt.title('Log Mel spectrogram')
plt.tight_layout()
plt.show()

# %%
# Extract MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sample_rate, n_mfcc=13)  # You can adjust the number of MFCC coefficients (n_mfcc)

# Save MFCCs as a CSV file
mfccs_df = pd.DataFrame(mfccs)
mfccs_df.to_csv("mfccs.csv", index=False)

# %%
# Visualize the MFCCs
plt.figure(figsize=(10, 4))

librosa.display.specshow(librosa.power_to_db(mfccs, ref=np.max), y_axis='mel', x_axis='time')

plt.colorbar(format='%+2.0f dB')

plt.title('MFCC')

plt.show()

# %%
#Computing ZERO-CROSSING RATE
# Zooming in (won't be necessary when segmentation is done)
n0 = 9000
n1 = 9100
zero_crossings = librosa.zero_crossings(y[n0:n1], pad=False)
print(sum(zero_crossings))
# Out:
# 49

# %%
#Pitch extraction
# Extract pitch with Crepe
time, frequency, confidence, activation = crepe.predict(y, sample_rate, viterbi=True)

# Print the estimated pitch (in Hz) at each time step
for t, f in zip(time, frequency):
    print(f"At time {t:.2f} seconds, estimated pitch is {f:.2f} Hz")


plt.figure(figsize=(10, 4))
plt.plot(time, frequency, label='Estimated pitch (Hz)')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.title('Pitch Contour')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 16/16 [==============================] - 3s 152ms/step
# At time 0.00 seconds, estimated pitch is 33.37 Hz
# At time 0.01 seconds, estimated pitch is 35.51 Hz
# At time 0.02 seconds, estimated pitch is 35.74 Hz
# At time 0.03 seconds, estimated pitch is 32.21 Hz
# At time 0.04 seconds, estimated pitch is 32.18 Hz
# At time 0.05 seconds, estimated pitch is 32.37 Hz
# At time 0.06 seconds, estimated pitch is 32.43 Hz
# At time 0.07 seconds, estimated pitch is 32.27 Hz
# At time 0.08 seconds, estimated pitch is 32.17 Hz
# At time 0.09 seconds, estimated pitch is 32.66 Hz
# At time 0.10 seconds, estimated pitch is 35.35 Hz
# At time 0.11 seconds, estimated pitch is 35.31 Hz
# At time 0.12 seconds, estimated pitch is 35.31 Hz
# At time 0.13 seconds, estimated pitch is 33.92 Hz
# At time 0.14 seconds, estimated pitch is 33.38 Hz
# At time 0.15 seconds, estimated pitch is 32.64 Hz
# At time 0.16 seconds, estimated pitch is 32.94 Hz
# At time 0.17 seconds, estimated pitch is 34.67 Hz
# At time 0.18 seconds, estimated pitch is 35.14 Hz
# At time 0.19 seconds, estimated pitch is 34.54 Hz
# At time 0.20 seconds, estimated pitch is 33.82 Hz
# At time 0.21 seconds, estimated pitch is 32.62 Hz
# At time 0.22 seconds, estimated pitch is 32.52 Hz
# At time 0.23 seconds, estimated pitch is 32.71 Hz
# At time 0.24 seconds, estimated pitch is 32.68 Hz
# At time 0.25 seconds, estimated pitch is 33.43 Hz
# At time 0.26 seconds, estimated pitch is 32.93 Hz
# At time 0.27 seconds, estimated pitch is 32.55 Hz
# At time 0.28 seconds, estimated pitch is 32.30 Hz
# At time 0.29 seconds, estimated pitch is 33.11 Hz
# At time 0.30 seconds, estimated pitch is 33.31 Hz
# At time 0.31 seconds, estimated pitch is 33.15 Hz
# At time 0.32 seconds, estimated pitch is 33.46 Hz
# At time 0.33 seconds, estimated pitch is 33.57 Hz
# At time 0.34 seconds, estimated pitch is 32.64 Hz
# At time 0.35 seconds, estimated pitch is 32.48 Hz
# At time 0.36 seconds, estimated pitch is 32.41 Hz
# At time 0.37 seconds, estimated pitch is 32.13 Hz
# At time 0.38 seconds, estimated pitch is 32.45 Hz
# At time 0.39 seconds, estimated pitch is 34.28 Hz
# At time 0.40 seconds, estimated pitch is 34.27 Hz
# At time 0.41 seconds, estimated pitch is 34.44 Hz
# At time 0.42 seconds, estimated pitch is 32.60 Hz
# At time 0.43 seconds, estimated pitch is 32.49 Hz
# At time 0.44 seconds, estimated pitch is 32.34 Hz
# At time 0.45 seconds, estimated pitch is 32.30 Hz
# At time 0.46 seconds, estimated pitch is 32.80 Hz
# At time 0.47 seconds, estimated pitch is 32.53 Hz
# At time 0.48 seconds, estimated pitch is 32.72 Hz
# At time 0.49 seconds, estimated pitch is 32.73 Hz
# At time 0.50 seconds, estimated pitch is 32.58 Hz
# At time 0.51 seconds, estimated pitch is 32.43 Hz
# At time 0.52 seconds, estimated pitch is 32.28 Hz
# At time 0.53 seconds, estimated pitch is 32.46 Hz
# At time 0.54 seconds, estimated pitch is 32.87 Hz
# At time 0.55 seconds, estimated pitch is 33.02 Hz
# At time 0.56 seconds, estimated pitch is 32.55 Hz
# At time 0.57 seconds, estimated pitch is 32.67 Hz
# At time 0.58 seconds, estimated pitch is 32.64 Hz
# At time 0.59 seconds, estimated pitch is 32.80 Hz
# At time 0.60 seconds, estimated pitch is 32.36 Hz
# At time 0.61 seconds, estimated pitch is 32.36 Hz
# At time 0.62 seconds, estimated pitch is 32.47 Hz
# At time 0.63 seconds, estimated pitch is 32.55 Hz
# At time 0.64 seconds, estimated pitch is 32.42 Hz
# At time 0.65 seconds, estimated pitch is 33.40 Hz
# At time 0.66 seconds, estimated pitch is 33.61 Hz
# At time 0.67 seconds, estimated pitch is 32.38 Hz
# At time 0.68 seconds, estimated pitch is 32.27 Hz
# At time 0.69 seconds, estimated pitch is 32.37 Hz
# At time 0.70 seconds, estimated pitch is 32.80 Hz
# At time 0.71 seconds, estimated pitch is 32.61 Hz
# At time 0.72 seconds, estimated pitch is 32.30 Hz
# At time 0.73 seconds, estimated pitch is 32.49 Hz
# At time 0.74 seconds, estimated pitch is 33.16 Hz
# At time 0.75 seconds, estimated pitch is 34.25 Hz
# At time 0.76 seconds, estimated pitch is 32.44 Hz
# At time 0.77 seconds, estimated pitch is 32.37 Hz
# At time 0.78 seconds, estimated pitch is 32.32 Hz
# At time 0.79 seconds, estimated pitch is 32.25 Hz
# At time 0.80 seconds, estimated pitch is 32.50 Hz
# At time 0.81 seconds, estimated pitch is 33.15 Hz
# At time 0.82 seconds, estimated pitch is 32.97 Hz
# At time 0.83 seconds, estimated pitch is 34.64 Hz
# At time 0.84 seconds, estimated pitch is 36.79 Hz
# At time 0.85 seconds, estimated pitch is 39.55 Hz
# At time 0.86 seconds, estimated pitch is 39.11 Hz
# At time 0.87 seconds, estimated pitch is 36.18 Hz
# At time 0.88 seconds, estimated pitch is 32.72 Hz
# At time 0.89 seconds, estimated pitch is 32.67 Hz
# At time 0.90 seconds, estimated pitch is 32.66 Hz
# At time 0.91 seconds, estimated pitch is 32.48 Hz
# At time 0.92 seconds, estimated pitch is 32.66 Hz
# At time 0.93 seconds, estimated pitch is 32.51 Hz
# At time 0.94 seconds, estimated pitch is 32.55 Hz
# At time 0.95 seconds, estimated pitch is 32.70 Hz
# At time 0.96 seconds, estimated pitch is 32.59 Hz
# At time 0.97 seconds, estimated pitch is 32.46 Hz
# At time 0.98 seconds, estimated pitch is 32.30 Hz
# At time 0.99 seconds, estimated pitch is 32.25 Hz
# At time 1.00 seconds, estimated pitch is 32.24 Hz
# At time 1.01 seconds, estimated pitch is 33.03 Hz
# At time 1.02 seconds, estimated pitch is 32.62 Hz
# At time 1.03 seconds, estimated pitch is 32.47 Hz
# At time 1.04 seconds, estimated pitch is 32.30 Hz
# At time 1.05 seconds, estimated pitch is 32.61 Hz
# At time 1.06 seconds, estimated pitch is 32.49 Hz
# At time 1.07 seconds, estimated pitch is 32.57 Hz
# At time 1.08 seconds, estimated pitch is 32.43 Hz
# At time 1.09 seconds, estimated pitch is 32.47 Hz
# At time 1.10 seconds, estimated pitch is 32.51 Hz
# At time 1.11 seconds, estimated pitch is 32.37 Hz
# At time 1.12 seconds, estimated pitch is 32.29 Hz
# At time 1.13 seconds, estimated pitch is 32.44 Hz
# At time 1.14 seconds, estimated pitch is 32.38 Hz
# At time 1.15 seconds, estimated pitch is 32.25 Hz
# At time 1.16 seconds, estimated pitch is 32.27 Hz
# At time 1.17 seconds, estimated pitch is 32.33 Hz
# At time 1.18 seconds, estimated pitch is 32.67 Hz
# At time 1.19 seconds, estimated pitch is 32.92 Hz
# At time 1.20 seconds, estimated pitch is 32.37 Hz
# At time 1.21 seconds, estimated pitch is 32.35 Hz
# At time 1.22 seconds, estimated pitch is 32.37 Hz
# At time 1.23 seconds, estimated pitch is 32.36 Hz
# At time 1.24 seconds, estimated pitch is 32.38 Hz
# At time 1.25 seconds, estimated pitch is 32.32 Hz
# At time 1.26 seconds, estimated pitch is 32.55 Hz
# At time 1.27 seconds, estimated pitch is 32.45 Hz
# At time 1.28 seconds, estimated pitch is 32.44 Hz
# At time 1.29 seconds, estimated pitch is 33.26 Hz
# At time 1.30 seconds, estimated pitch is 33.30 Hz
# At time 1.31 seconds, estimated pitch is 32.48 Hz
# At time 1.32 seconds, estimated pitch is 32.21 Hz
# At time 1.33 seconds, estimated pitch is 32.27 Hz
# At time 1.34 seconds, estimated pitch is 32.58 Hz
# At time 1.35 seconds, estimated pitch is 32.77 Hz
# At time 1.36 seconds, estimated pitch is 32.39 Hz
# At time 1.37 seconds, estimated pitch is 32.46 Hz
# At time 1.38 seconds, estimated pitch is 32.54 Hz
# At time 1.39 seconds, estimated pitch is 32.71 Hz
# At time 1.40 seconds, estimated pitch is 34.31 Hz
# At time 1.41 seconds, estimated pitch is 34.38 Hz
# At time 1.42 seconds, estimated pitch is 33.90 Hz
# At time 1.43 seconds, estimated pitch is 33.76 Hz
# At time 1.44 seconds, estimated pitch is 33.07 Hz
# At time 1.45 seconds, estimated pitch is 33.54 Hz
# At time 1.46 seconds, estimated pitch is 33.70 Hz
# At time 1.47 seconds, estimated pitch is 34.10 Hz
# At time 1.48 seconds, estimated pitch is 35.97 Hz
# At time 1.49 seconds, estimated pitch is 39.47 Hz
# At time 1.50 seconds, estimated pitch is 39.06 Hz
# At time 1.51 seconds, estimated pitch is 38.52 Hz
# At time 1.52 seconds, estimated pitch is 36.79 Hz
# At time 1.53 seconds, estimated pitch is 33.61 Hz
# At time 1.54 seconds, estimated pitch is 32.69 Hz
# At time 1.55 seconds, estimated pitch is 32.45 Hz
# At time 1.56 seconds, estimated pitch is 32.33 Hz
# At time 1.57 seconds, estimated pitch is 32.16 Hz
# At time 1.58 seconds, estimated pitch is 32.38 Hz
# At time 1.59 seconds, estimated pitch is 34.02 Hz
# At time 1.60 seconds, estimated pitch is 34.13 Hz
# At time 1.61 seconds, estimated pitch is 33.60 Hz
# At time 1.62 seconds, estimated pitch is 32.98 Hz
# At time 1.63 seconds, estimated pitch is 32.12 Hz
# At time 1.64 seconds, estimated pitch is 32.35 Hz
# At time 1.65 seconds, estimated pitch is 32.48 Hz
# At time 1.66 seconds, estimated pitch is 32.46 Hz
# At time 1.67 seconds, estimated pitch is 32.68 Hz
# At time 1.68 seconds, estimated pitch is 33.39 Hz
# At time 1.69 seconds, estimated pitch is 35.26 Hz
# At time 1.70 seconds, estimated pitch is 35.32 Hz
# At time 1.71 seconds, estimated pitch is 32.93 Hz
# At time 1.72 seconds, estimated pitch is 32.19 Hz
# At time 1.73 seconds, estimated pitch is 32.33 Hz
# At time 1.74 seconds, estimated pitch is 33.52 Hz
# At time 1.75 seconds, estimated pitch is 32.93 Hz
# At time 1.76 seconds, estimated pitch is 33.01 Hz
# At time 1.77 seconds, estimated pitch is 32.36 Hz
# At time 1.78 seconds, estimated pitch is 32.51 Hz
# At time 1.79 seconds, estimated pitch is 32.52 Hz
# At time 1.80 seconds, estimated pitch is 33.12 Hz
# At time 1.81 seconds, estimated pitch is 33.29 Hz
# At time 1.82 seconds, estimated pitch is 33.94 Hz
# At time 1.83 seconds, estimated pitch is 32.71 Hz
# At time 1.84 seconds, estimated pitch is 32.55 Hz
# At time 1.85 seconds, estimated pitch is 32.46 Hz
# At time 1.86 seconds, estimated pitch is 32.47 Hz
# At time 1.87 seconds, estimated pitch is 32.59 Hz
# At time 1.88 seconds, estimated pitch is 32.64 Hz
# At time 1.89 seconds, estimated pitch is 32.48 Hz
# At time 1.90 seconds, estimated pitch is 32.33 Hz
# At time 1.91 seconds, estimated pitch is 32.39 Hz
# At time 1.92 seconds, estimated pitch is 32.39 Hz
# At time 1.93 seconds, estimated pitch is 32.17 Hz
# At time 1.94 seconds, estimated pitch is 32.35 Hz
# At time 1.95 seconds, estimated pitch is 32.52 Hz
# At time 1.96 seconds, estimated pitch is 33.61 Hz
# At time 1.97 seconds, estimated pitch is 32.81 Hz
# At time 1.98 seconds, estimated pitch is 32.60 Hz
# At time 1.99 seconds, estimated pitch is 32.48 Hz
# At time 2.00 seconds, estimated pitch is 34.62 Hz
# At time 2.01 seconds, estimated pitch is 33.95 Hz
# At time 2.02 seconds, estimated pitch is 32.44 Hz
# At time 2.03 seconds, estimated pitch is 32.51 Hz
# At time 2.04 seconds, estimated pitch is 32.37 Hz
# At time 2.05 seconds, estimated pitch is 32.41 Hz
# At time 2.06 seconds, estimated pitch is 32.33 Hz
# At time 2.07 seconds, estimated pitch is 32.36 Hz
# At time 2.08 seconds, estimated pitch is 34.48 Hz
# At time 2.09 seconds, estimated pitch is 34.42 Hz
# At time 2.10 seconds, estimated pitch is 32.67 Hz
# At time 2.11 seconds, estimated pitch is 32.26 Hz
# At time 2.12 seconds, estimated pitch is 32.19 Hz
# At time 2.13 seconds, estimated pitch is 32.21 Hz
# At time 2.14 seconds, estimated pitch is 32.45 Hz
# At time 2.15 seconds, estimated pitch is 32.58 Hz
# At time 2.16 seconds, estimated pitch is 33.68 Hz
# At time 2.17 seconds, estimated pitch is 33.55 Hz
# At time 2.18 seconds, estimated pitch is 32.66 Hz
# At time 2.19 seconds, estimated pitch is 32.38 Hz
# At time 2.20 seconds, estimated pitch is 32.37 Hz
# At time 2.21 seconds, estimated pitch is 32.44 Hz
# At time 2.22 seconds, estimated pitch is 32.34 Hz
# At time 2.23 seconds, estimated pitch is 32.13 Hz
# At time 2.24 seconds, estimated pitch is 32.06 Hz
# At time 2.25 seconds, estimated pitch is 32.27 Hz
# At time 2.26 seconds, estimated pitch is 32.44 Hz
# At time 2.27 seconds, estimated pitch is 32.50 Hz
# At time 2.28 seconds, estimated pitch is 32.89 Hz
# At time 2.29 seconds, estimated pitch is 32.55 Hz
# At time 2.30 seconds, estimated pitch is 32.63 Hz
# At time 2.31 seconds, estimated pitch is 32.44 Hz
# At time 2.32 seconds, estimated pitch is 32.45 Hz
# At time 2.33 seconds, estimated pitch is 32.53 Hz
# At time 2.34 seconds, estimated pitch is 33.53 Hz
# At time 2.35 seconds, estimated pitch is 32.61 Hz
# At time 2.36 seconds, estimated pitch is 32.37 Hz
# At time 2.37 seconds, estimated pitch is 32.09 Hz
# At time 2.38 seconds, estimated pitch is 32.23 Hz
# At time 2.39 seconds, estimated pitch is 32.18 Hz
# At time 2.40 seconds, estimated pitch is 32.14 Hz
# At time 2.41 seconds, estimated pitch is 32.02 Hz
# At time 2.42 seconds, estimated pitch is 32.28 Hz
# At time 2.43 seconds, estimated pitch is 32.94 Hz
# At time 2.44 seconds, estimated pitch is 32.36 Hz
# At time 2.45 seconds, estimated pitch is 32.39 Hz
# At time 2.46 seconds, estimated pitch is 33.38 Hz
# At time 2.47 seconds, estimated pitch is 32.24 Hz
# At time 2.48 seconds, estimated pitch is 32.31 Hz
# At time 2.49 seconds, estimated pitch is 32.60 Hz
# At time 2.50 seconds, estimated pitch is 32.46 Hz
# At time 2.51 seconds, estimated pitch is 32.27 Hz
# At time 2.52 seconds, estimated pitch is 32.36 Hz
# At time 2.53 seconds, estimated pitch is 32.61 Hz
# At time 2.54 seconds, estimated pitch is 32.63 Hz
# At time 2.55 seconds, estimated pitch is 32.64 Hz
# At time 2.56 seconds, estimated pitch is 32.43 Hz
# At time 2.57 seconds, estimated pitch is 32.31 Hz
# At time 2.58 seconds, estimated pitch is 32.34 Hz
# At time 2.59 seconds, estimated pitch is 32.28 Hz
# At time 2.60 seconds, estimated pitch is 32.28 Hz
# At time 2.61 seconds, estimated pitch is 32.17 Hz
# At time 2.62 seconds, estimated pitch is 32.10 Hz
# At time 2.63 seconds, estimated pitch is 32.23 Hz
# At time 2.64 seconds, estimated pitch is 32.42 Hz
# At time 2.65 seconds, estimated pitch is 32.44 Hz
# At time 2.66 seconds, estimated pitch is 32.21 Hz
# At time 2.67 seconds, estimated pitch is 32.19 Hz
# At time 2.68 seconds, estimated pitch is 32.12 Hz
# At time 2.69 seconds, estimated pitch is 32.08 Hz
# At time 2.70 seconds, estimated pitch is 32.24 Hz
# At time 2.71 seconds, estimated pitch is 32.72 Hz
# At time 2.72 seconds, estimated pitch is 32.80 Hz
# At time 2.73 seconds, estimated pitch is 32.71 Hz
# At time 2.74 seconds, estimated pitch is 32.63 Hz
# At time 2.75 seconds, estimated pitch is 32.54 Hz
# At time 2.76 seconds, estimated pitch is 32.78 Hz
# At time 2.77 seconds, estimated pitch is 32.61 Hz
# At time 2.78 seconds, estimated pitch is 32.18 Hz
# At time 2.79 seconds, estimated pitch is 32.00 Hz
# At time 2.80 seconds, estimated pitch is 32.04 Hz
# At time 2.81 seconds, estimated pitch is 32.15 Hz
# At time 2.82 seconds, estimated pitch is 34.88 Hz
# At time 2.83 seconds, estimated pitch is 33.30 Hz
# At time 2.84 seconds, estimated pitch is 32.45 Hz
# At time 2.85 seconds, estimated pitch is 32.34 Hz
# At time 2.86 seconds, estimated pitch is 32.33 Hz
# At time 2.87 seconds, estimated pitch is 32.30 Hz
# At time 2.88 seconds, estimated pitch is 32.40 Hz
# At time 2.89 seconds, estimated pitch is 32.55 Hz
# At time 2.90 seconds, estimated pitch is 32.51 Hz
# At time 2.91 seconds, estimated pitch is 32.44 Hz
# At time 2.92 seconds, estimated pitch is 32.35 Hz
# At time 2.93 seconds, estimated pitch is 32.28 Hz
# At time 2.94 seconds, estimated pitch is 32.49 Hz
# At time 2.95 seconds, estimated pitch is 32.67 Hz
# At time 2.96 seconds, estimated pitch is 33.12 Hz
# At time 2.97 seconds, estimated pitch is 33.21 Hz
# At time 2.98 seconds, estimated pitch is 33.17 Hz
# At time 2.99 seconds, estimated pitch is 35.24 Hz
# At time 3.00 seconds, estimated pitch is 37.93 Hz
# At time 3.01 seconds, estimated pitch is 38.08 Hz
# At time 3.02 seconds, estimated pitch is 38.65 Hz
# At time 3.03 seconds, estimated pitch is 39.64 Hz
# At time 3.04 seconds, estimated pitch is 40.41 Hz
# At time 3.05 seconds, estimated pitch is 40.52 Hz
# At time 3.06 seconds, estimated pitch is 39.27 Hz
# At time 3.07 seconds, estimated pitch is 37.56 Hz
# At time 3.08 seconds, estimated pitch is 35.57 Hz
# At time 3.09 seconds, estimated pitch is 34.85 Hz
# At time 3.10 seconds, estimated pitch is 35.13 Hz
# At time 3.11 seconds, estimated pitch is 32.96 Hz
# At time 3.12 seconds, estimated pitch is 32.55 Hz
# At time 3.13 seconds, estimated pitch is 32.50 Hz
# At time 3.14 seconds, estimated pitch is 32.46 Hz
# At time 3.15 seconds, estimated pitch is 32.28 Hz
# At time 3.16 seconds, estimated pitch is 32.33 Hz
# At time 3.17 seconds, estimated pitch is 32.47 Hz
# At time 3.18 seconds, estimated pitch is 34.20 Hz
# At time 3.19 seconds, estimated pitch is 38.30 Hz
# At time 3.20 seconds, estimated pitch is 38.21 Hz
# At time 3.21 seconds, estimated pitch is 38.58 Hz
# At time 3.22 seconds, estimated pitch is 40.21 Hz
# At time 3.23 seconds, estimated pitch is 40.43 Hz
# At time 3.24 seconds, estimated pitch is 37.41 Hz
# At time 3.25 seconds, estimated pitch is 33.59 Hz
# At time 3.26 seconds, estimated pitch is 32.31 Hz
# At time 3.27 seconds, estimated pitch is 32.12 Hz
# At time 3.28 seconds, estimated pitch is 32.30 Hz
# At time 3.29 seconds, estimated pitch is 32.30 Hz
# At time 3.30 seconds, estimated pitch is 32.39 Hz
# At time 3.31 seconds, estimated pitch is 32.35 Hz
# At time 3.32 seconds, estimated pitch is 32.45 Hz
# At time 3.33 seconds, estimated pitch is 33.11 Hz
# At time 3.34 seconds, estimated pitch is 33.29 Hz
# At time 3.35 seconds, estimated pitch is 32.55 Hz
# At time 3.36 seconds, estimated pitch is 32.47 Hz
# At time 3.37 seconds, estimated pitch is 32.58 Hz
# At time 3.38 seconds, estimated pitch is 32.97 Hz
# At time 3.39 seconds, estimated pitch is 32.98 Hz
# At time 3.40 seconds, estimated pitch is 33.17 Hz
# At time 3.41 seconds, estimated pitch is 33.08 Hz
# At time 3.42 seconds, estimated pitch is 32.32 Hz
# At time 3.43 seconds, estimated pitch is 32.33 Hz
# At time 3.44 seconds, estimated pitch is 33.04 Hz
# At time 3.45 seconds, estimated pitch is 32.91 Hz
# At time 3.46 seconds, estimated pitch is 32.60 Hz
# At time 3.47 seconds, estimated pitch is 32.25 Hz
# At time 3.48 seconds, estimated pitch is 32.24 Hz
# At time 3.49 seconds, estimated pitch is 32.36 Hz
# At time 3.50 seconds, estimated pitch is 33.28 Hz
# At time 3.51 seconds, estimated pitch is 36.23 Hz
# At time 3.52 seconds, estimated pitch is 35.59 Hz
# At time 3.53 seconds, estimated pitch is 35.52 Hz
# At time 3.54 seconds, estimated pitch is 35.21 Hz
# At time 3.55 seconds, estimated pitch is 33.89 Hz
# At time 3.56 seconds, estimated pitch is 33.79 Hz
# At time 3.57 seconds, estimated pitch is 33.57 Hz
# At time 3.58 seconds, estimated pitch is 33.32 Hz
# At time 3.59 seconds, estimated pitch is 33.07 Hz
# At time 3.60 seconds, estimated pitch is 32.30 Hz
# At time 3.61 seconds, estimated pitch is 32.39 Hz
# At time 3.62 seconds, estimated pitch is 32.33 Hz
# At time 3.63 seconds, estimated pitch is 32.26 Hz
# At time 3.64 seconds, estimated pitch is 32.17 Hz
# At time 3.65 seconds, estimated pitch is 32.38 Hz
# At time 3.66 seconds, estimated pitch is 32.48 Hz
# At time 3.67 seconds, estimated pitch is 32.41 Hz
# At time 3.68 seconds, estimated pitch is 32.31 Hz
# At time 3.69 seconds, estimated pitch is 32.68 Hz
# At time 3.70 seconds, estimated pitch is 32.68 Hz
# At time 3.71 seconds, estimated pitch is 32.60 Hz
# At time 3.72 seconds, estimated pitch is 32.71 Hz
# At time 3.73 seconds, estimated pitch is 33.25 Hz
# At time 3.74 seconds, estimated pitch is 32.60 Hz
# At time 3.75 seconds, estimated pitch is 32.61 Hz
# At time 3.76 seconds, estimated pitch is 32.59 Hz
# At time 3.77 seconds, estimated pitch is 33.96 Hz
# At time 3.78 seconds, estimated pitch is 33.69 Hz
# At time 3.79 seconds, estimated pitch is 34.35 Hz
# At time 3.80 seconds, estimated pitch is 35.05 Hz
# At time 3.81 seconds, estimated pitch is 34.96 Hz
# At time 3.82 seconds, estimated pitch is 34.92 Hz
# At time 3.83 seconds, estimated pitch is 35.20 Hz
# At time 3.84 seconds, estimated pitch is 36.28 Hz
# At time 3.85 seconds, estimated pitch is 37.54 Hz
# At time 3.86 seconds, estimated pitch is 38.50 Hz
# At time 3.87 seconds, estimated pitch is 38.75 Hz
# At time 3.88 seconds, estimated pitch is 37.40 Hz
# At time 3.89 seconds, estimated pitch is 34.80 Hz
# At time 3.90 seconds, estimated pitch is 34.02 Hz
# At time 3.91 seconds, estimated pitch is 33.74 Hz
# At time 3.92 seconds, estimated pitch is 33.19 Hz
# At time 3.93 seconds, estimated pitch is 32.53 Hz
# At time 3.94 seconds, estimated pitch is 32.50 Hz
# At time 3.95 seconds, estimated pitch is 32.52 Hz
# At time 3.96 seconds, estimated pitch is 32.93 Hz
# At time 3.97 seconds, estimated pitch is 33.00 Hz
# At time 3.98 seconds, estimated pitch is 32.49 Hz
# At time 3.99 seconds, estimated pitch is 32.67 Hz
# At time 4.00 seconds, estimated pitch is 32.61 Hz
# At time 4.01 seconds, estimated pitch is 32.45 Hz
# At time 4.02 seconds, estimated pitch is 32.67 Hz
# At time 4.03 seconds, estimated pitch is 35.57 Hz
# At time 4.04 seconds, estimated pitch is 35.16 Hz
# At time 4.05 seconds, estimated pitch is 34.43 Hz
# At time 4.06 seconds, estimated pitch is 32.71 Hz
# At time 4.07 seconds, estimated pitch is 32.58 Hz
# At time 4.08 seconds, estimated pitch is 32.59 Hz
# At time 4.09 seconds, estimated pitch is 32.42 Hz
# At time 4.10 seconds, estimated pitch is 32.40 Hz
# At time 4.11 seconds, estimated pitch is 32.35 Hz
# At time 4.12 seconds, estimated pitch is 32.60 Hz
# At time 4.13 seconds, estimated pitch is 33.85 Hz
# At time 4.14 seconds, estimated pitch is 32.97 Hz
# At time 4.15 seconds, estimated pitch is 33.26 Hz
# At time 4.16 seconds, estimated pitch is 32.48 Hz
# At time 4.17 seconds, estimated pitch is 32.42 Hz
# At time 4.18 seconds, estimated pitch is 32.57 Hz
# At time 4.19 seconds, estimated pitch is 32.49 Hz
# At time 4.20 seconds, estimated pitch is 32.46 Hz
# At time 4.21 seconds, estimated pitch is 33.14 Hz
# At time 4.22 seconds, estimated pitch is 32.61 Hz
# At time 4.23 seconds, estimated pitch is 32.48 Hz
# At time 4.24 seconds, estimated pitch is 32.55 Hz
# At time 4.25 seconds, estimated pitch is 32.75 Hz
# At time 4.26 seconds, estimated pitch is 32.82 Hz
# At time 4.27 seconds, estimated pitch is 32.72 Hz
# At time 4.28 seconds, estimated pitch is 32.68 Hz
# At time 4.29 seconds, estimated pitch is 32.52 Hz
# At time 4.30 seconds, estimated pitch is 32.34 Hz
# At time 4.31 seconds, estimated pitch is 32.23 Hz
# At time 4.32 seconds, estimated pitch is 32.08 Hz
# At time 4.33 seconds, estimated pitch is 32.06 Hz
# At time 4.34 seconds, estimated pitch is 32.16 Hz
# At time 4.35 seconds, estimated pitch is 32.37 Hz
# At time 4.36 seconds, estimated pitch is 32.67 Hz
# At time 4.37 seconds, estimated pitch is 33.56 Hz
# At time 4.38 seconds, estimated pitch is 32.71 Hz
# At time 4.39 seconds, estimated pitch is 32.62 Hz
# At time 4.40 seconds, estimated pitch is 32.54 Hz
# At time 4.41 seconds, estimated pitch is 32.32 Hz
# At time 4.42 seconds, estimated pitch is 32.30 Hz
# At time 4.43 seconds, estimated pitch is 32.42 Hz
# At time 4.44 seconds, estimated pitch is 32.42 Hz
# At time 4.45 seconds, estimated pitch is 32.40 Hz
# At time 4.46 seconds, estimated pitch is 32.48 Hz
# At time 4.47 seconds, estimated pitch is 32.59 Hz
# At time 4.48 seconds, estimated pitch is 32.84 Hz
# At time 4.49 seconds, estimated pitch is 32.35 Hz
# At time 4.50 seconds, estimated pitch is 32.13 Hz
# At time 4.51 seconds, estimated pitch is 32.33 Hz
# At time 4.52 seconds, estimated pitch is 32.37 Hz
# At time 4.53 seconds, estimated pitch is 32.37 Hz
# At time 4.54 seconds, estimated pitch is 32.41 Hz
# At time 4.55 seconds, estimated pitch is 32.29 Hz
# At time 4.56 seconds, estimated pitch is 32.20 Hz
# At time 4.57 seconds, estimated pitch is 32.32 Hz
# At time 4.58 seconds, estimated pitch is 32.44 Hz
# At time 4.59 seconds, estimated pitch is 32.31 Hz
# At time 4.60 seconds, estimated pitch is 32.30 Hz
# At time 4.61 seconds, estimated pitch is 32.44 Hz
# At time 4.62 seconds, estimated pitch is 32.51 Hz
# At time 4.63 seconds, estimated pitch is 32.51 Hz
# At time 4.64 seconds, estimated pitch is 32.63 Hz
# At time 4.65 seconds, estimated pitch is 33.45 Hz
# At time 4.66 seconds, estimated pitch is 32.46 Hz
# At time 4.67 seconds, estimated pitch is 32.25 Hz
# At time 4.68 seconds, estimated pitch is 32.36 Hz
# At time 4.69 seconds, estimated pitch is 33.04 Hz
# At time 4.70 seconds, estimated pitch is 32.94 Hz
# At time 4.71 seconds, estimated pitch is 32.37 Hz
# At time 4.72 seconds, estimated pitch is 32.25 Hz
# At time 4.73 seconds, estimated pitch is 32.51 Hz
# At time 4.74 seconds, estimated pitch is 32.70 Hz
# At time 4.75 seconds, estimated pitch is 32.48 Hz
# At time 4.76 seconds, estimated pitch is 32.34 Hz
# At time 4.77 seconds, estimated pitch is 33.12 Hz
# At time 4.78 seconds, estimated pitch is 33.17 Hz
# At time 4.79 seconds, estimated pitch is 33.29 Hz
# At time 4.80 seconds, estimated pitch is 34.11 Hz
# At time 4.81 seconds, estimated pitch is 35.42 Hz
# At time 4.82 seconds, estimated pitch is 35.14 Hz
# At time 4.83 seconds, estimated pitch is 33.05 Hz
# At time 4.84 seconds, estimated pitch is 33.26 Hz
# At time 4.85 seconds, estimated pitch is 34.04 Hz
# At time 4.86 seconds, estimated pitch is 32.37 Hz
# At time 4.87 seconds, estimated pitch is 32.40 Hz
# At time 4.88 seconds, estimated pitch is 32.35 Hz
# At time 4.89 seconds, estimated pitch is 32.28 Hz
# At time 4.90 seconds, estimated pitch is 32.11 Hz
# At time 4.91 seconds, estimated pitch is 34.28 Hz
# At time 4.92 seconds, estimated pitch is 34.52 Hz
# At time 4.93 seconds, estimated pitch is 34.04 Hz
# At time 4.94 seconds, estimated pitch is 33.23 Hz
# At time 4.95 seconds, estimated pitch is 32.93 Hz
# At time 4.96 seconds, estimated pitch is 33.23 Hz
# At time 4.97 seconds, estimated pitch is 33.71 Hz
# At time 4.98 seconds, estimated pitch is 33.35 Hz
# At time 4.99 seconds, estimated pitch is 32.48 Hz
# At time 5.00 seconds, estimated pitch is 32.53 Hz

# %%
#Spectral centroid
spectral_centroids = librosa.feature.spectral_centroid(y=y, sr=sample_rate)[0]

# Computing the time variable for visualization
plt.figure(figsize=(20,5))
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)

# Normalising the spectral centroid for visualisation
def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)

# Plot the audio signal
plt.subplot(2, 1, 1)
plt.plot(librosa.times_like(y, sr=sample_rate), y, label='Audio Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Signal')
plt.legend()

# Plot the spectral bandwidth
plt.subplot(2, 1, 2)
plt.plot(t, spectral_centroids, label='Spectral Bandwidth', color='red')
plt.xlabel('Time (s)')
plt.ylabel('Hz')
plt.title('Spectral Centroids over Time')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Spectral centroid
# ----> 2 spectral_centroids = librosa.feature.spectral_centroid(y=y, sr=sample_rate)[0]
#       4 # Computing the time variable for visualization
#       5 plt.figure(figsize=(20,5))
#
# NameError: name 'librosa' is not defined
