# %%
# IMPORTS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa

from IPython.display import Audio

# %% [markdown]
# #### Get Observation

# %%
def get_observation(i, pitch, time, annotations_df, timestep): # TODO: ¿¿Afegir parametres per passar les altres 3 funcions aqui directament??
    row = annotations_df.loc[i]
    label = row.label
    
    start = round(row.start / timestep)
    end = round(row.end / timestep)
    """ start_sr = round(row.start * sampling_rate)
    end_sr = round(row.end * sampling_rate) """
    
    pitch_sample = pitch[start:end]
    time_sample = time[start:end]
    """ audio_sample = audio_file[start_sr:end_sr] """
    
    return pitch_sample, time_sample, label

# %%
pitch_sample, time_sample, label = get_observation(3, pitch, time, annotations, timestep)

# %%
# Plot time series and pitch
plt.plot(time_sample, pitch_sample)
plt.title(f'{label}')
plt.ylabel('Pitch (Hz)')
plt.xlabel('Time (s)')
# Out:
# Text(0.5, 0, 'Time (s)')
